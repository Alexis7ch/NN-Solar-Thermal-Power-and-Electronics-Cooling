# %%
import numpy as np

# %%
#import useful packages
import keras
import pandas as pd
from keras.models import Sequential
import numpy as np
import keras.backend as kb
import tensorflow as tf
#the follwoing 2 lines are only needed for Mac OS machines
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Part 1

# %% [markdown]
# ### Task 1.1

# %%
import numpy

xdata = []
ydata = []
#xdata.append([ Di(m), qoflux (kW/m^2), mdot (kg/s)])



xdata.append([0.008, 550, 0.06157])
xdata.append([0.008, 650, 0.07269])
xdata.append([0.008, 750, 0.08396])
xdata.append([0.008, 850, 0.09347])
xdata.append([0.008, 950, 0.10635])
xdata.append([0.008, 1050, 0.11521])
xdata.append([0.008, 1150, 0.1287])
xdata.append([0.008, 850, 0.09516])
xdata.append([0.008, 550, 0.04398])
xdata.append([0.008, 750, 0.05997])
xdata.append([0.008, 950, 0.07596])
xdata.append([0.008, 1050, 0.08343])
xdata.append([0.008, 1150, 0.0919])
xdata.append([0.008, 850, 0.06797])
xdata.append([0.008, 550, 0.0342])
xdata.append([0.008, 750, 0.04664])
xdata.append([0.008, 950, 0.05908])
xdata.append([0.008, 1150, 0.0715])
xdata.append([0.008, 850, 0.05286])
xdata.append([0.011, 550, 0.0846])
xdata.append([0.011, 750, 0.1154])
xdata.append([0.011, 950, 0.1462])
xdata.append([0.011, 1150, 0.177])
xdata.append([0.011, 850, 0.1308])
xdata.append([0.011, 550, 0.06047])
xdata.append([0.011, 750, 0.08246])
xdata.append([0.011, 950, 0.1044])
xdata.append([0.011, 1050, 0.1134])
xdata.append([0.011, 1150, 0.1264])
xdata.append([0.011, 850, 0.0934])
xdata.append([0.011, 550, 0.047])
xdata.append([0.011, 750, 0.06413])
xdata.append([0.011, 950, 0.08124])
xdata.append([0.011, 1150, 0.09834])
xdata.append([0.011, 850, 0.072691])
xdata.append([0.011, 700, 0.087196])
xdata.append([0.013, 550, 0.10005])
xdata.append([0.013, 750, 0.13644])
xdata.append([0.013, 950, 0.17282])
xdata.append([0.013, 1150, 0.2092])
xdata.append([0.013, 850, 0.15463])
xdata.append([0.013, 550, 0.07147])
xdata.append([0.013, 750, 0.09745])
xdata.append([0.013, 950, 0.12344])
xdata.append([0.013, 1050, 0.13302])
xdata.append([0.013, 1150, 0.1494])
xdata.append([0.013, 850, 0.11045])
xdata.append([0.013, 550, 0.05558])
xdata.append([0.013, 750, 0.0758])
xdata.append([0.013, 950, 0.09601])
xdata.append([0.013, 1150, 0.1162])
xdata.append([0.013, 850, 0.0859])

#ydata.append([ exit quality, max wall temperature (deg C)])

ydata.append([0.525, 306.7])
ydata.append([0.525, 298.5])
ydata.append([0.525, 294.5])
ydata.append([0.525, 290.2])
ydata.append([0.524, 286.9])
ydata.append([0.524, 284.1])
ydata.append([0.525, 281.7])
ydata.append([0.524, 290.3])
ydata.append([0.734, 307.9])
ydata.append([0.735, 295.5])
ydata.append([0.735, 287.8])
ydata.append([0.735, 285.0])
ydata.append([0.735, 282.5])
ydata.append([0.734, 291.3])
ydata.append([ 0.945, 308.6])
ydata.append([0.945, 296.2])
ydata.append([0.945, 288.5])
ydata.append([0.945, 283.1])
ydata.append([0.945, 291.9])
ydata.append([ 0.525, 328.0])
ydata.append([0.525, 311.2])
ydata.append([0.525, 300.8])
ydata.append([0.525, 293.6])
ydata.append([0.525, 305.5])
ydata.append([0.735, 329.6])
ydata.append([0.735, 312.6])
ydata.append([0.735, 302.0])
ydata.append([0.735, 299.4])
ydata.append([0.735, 294.8])
ydata.append([0.735, 306.8])
ydata.append([ 0.945, 330.7])
ydata.append([0.945, 313.6])
ydata.append([0.944, 302.9])
ydata.append([0.945, 295.6])
ydata.append([0.944, 307.7])
ydata.append([0.734, 324.7])
ydata.append([0.525, 342.2])
ydata.append([0.524,  322.3])
ydata.append([0.524, 310.0])
ydata.append([0.525, 301.6])
ydata.append([0.524, 315.5])
ydata.append([0.734, 344.1])
ydata.append([0.735, 324.0])
ydata.append([0.735, 311.5])
ydata.append([0.735, 306.3])
ydata.append([0.735, 302.9])
ydata.append([0.734, 317.1])
ydata.append([0.945, 345.3])
ydata.append([0.944, 325.1])
ydata.append([0.944, 312.5])
ydata.append([0.945, 303.9])
ydata.append([0.945, 318.2])

xarray= numpy.array(xdata)
yarray= numpy.array(ydata)
#print (xdata)
#print (xarray)
#print (ydata)
#print (yarray)

# %%
x_median = np.median(xarray, 0)
DI_med = x_median[0] ###Median for the first input:Tube inside diameter Di (m)
qoflux_med = x_median[1]
mdot_med = x_median[2]
print('Median of each input:', x_median)
x_norm = xarray/x_median
#print('Normalized array: ', x_norm)

y_median = np.median(yarray, 0)
xe_med = y_median[0] ###Median for the first output: exit quality xe 
Tw_med = y_median[1] ###Same for maximum tube wall temperature (°C)
print('xe median :', xe_med)

y_norm = yarray/y_median
#print('Normalized output array:', y_norm)
# Out:
# Median of each input: [1.100e-02 8.500e+02 9.265e-02]
# xe median : 0.735

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_norm, y_norm, test_size=0.25, random_state = 7)

# %%
print('Length of training set:', len(x_train))
#print(len(y_train))
print('Length of testing set:', len(x_test))
print('Length of the entire set:', len(x_norm))
#print(y_train)
#print(x_train)
# Out:
# Length of training set: 39
# Length of testing set: 13
# Length of the entire set: 52

# %%
from keras import backend as K
initializer = keras.initializers.RandomUniform(minval= -0.2, maxval=0.5)

model = keras.Sequential([
    keras.layers.Dense(6, activation=K.elu, input_shape=[3],  kernel_initializer=initializer),
    keras.layers.Dense(8, activation=K.elu,  kernel_initializer=initializer),
    keras.layers.Dense(16, activation=K.elu,  kernel_initializer=initializer),
    keras.layers.Dense(8, activation=K.elu, kernel_initializer=initializer),
    keras.layers.Dense(2,  kernel_initializer=initializer)
  ])

# %%
rms = keras.optimizers.RMSprop(0.0030)
model.compile(loss='mean_absolute_error',optimizer=rms)

# %%
# Add an early stopping callback
es = keras.callbacks.EarlyStopping(
    monitor='loss', 
    mode='min', 
    patience = 130, 
    restore_best_weights = True, 
    verbose=1)
# Add a checkpoint where loss is minimum, and save that model
mc = keras.callbacks.ModelCheckpoint('best_model.SB', monitor='loss', 
                     mode='min',  verbose=1, save_best_only=True)
import os
root_logdir = os.path.join(os.curdir, "my_logs")

def get_run_logdir():
    import time
    run_id = time.strftime("run_P1_1_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)
run_logdir = get_run_logdir()

tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

#historyData = model.fit(x_train, y_train,epochs=800,callbacks=[es, tensorboard_cb], validation_data = (x_test, y_test))
historyData = model.fit(x_train,y_train,epochs=800,callbacks=[es, tensorboard_cb])

loss_hist = historyData.history['loss']
#The above line will return a dictionary, access it's info like this:
best_epoch = np.argmin(historyData.history['loss']) + 1
print ('best epoch = ', best_epoch)
print('smallest loss =', np.min(loss_hist))

model.save('./best_model')
# Out:
# Epoch 1/800
# 39/39 [==============================] - 0s 595us/step - loss: 0.0442
# Epoch 2/800
# 39/39 [==============================] - 0s 158us/step - loss: 0.0510
# Epoch 3/800
# 39/39 [==============================] - 0s 178us/step - loss: 0.0398
# Epoch 4/800
# 39/39 [==============================] - 0s 139us/step - loss: 0.0337
# Epoch 5/800
# 39/39 [==============================] - 0s 124us/step - loss: 0.0463
# Epoch 6/800
# 39/39 [==============================] - 0s 173us/step - loss: 0.0494
# Epoch 7/800
# 39/39 [==============================] - 0s 135us/step - loss: 0.0601
# Epoch 8/800
# 39/39 [==============================] - 0s 167us/step - loss: 0.0624
# Epoch 9/800
# 39/39 [==============================] - 0s 147us/step - loss: 0.0417
# Epoch 10/800
# 39/39 [==============================] - 0s 141us/step - loss: 0.0602
# Epoch 11/800
# 39/39 [==============================] - 0s 130us/step - loss: 0.0586
# Epoch 12/800
# ...

# %%
recon_model = keras.models.load_model("best_model")

# %% [markdown]
# ### Predictions on the training dataset

# %%
#Getting the predicted outputs by the model:
y_pred = []
for i in range(len(x_train)):
    xrow = [[x_train[i][0] , x_train[i][1] , x_train[i][2]]]
    out = model.predict(np.array(xrow))
    y_pred.append(out) 
y_pred = np.concatenate(y_pred, axis=0 )

# %%
import matplotlib.pyplot as plt
xe_data = [y_train[i][0] * xe_med for i in range(len(y_train))]
xe_pred = [y_pred[i][0] *xe_med for i in range(len(y_pred))]

Tw_train = [y_train[i][1]*Tw_med for i in range(len(y_train))]
Tw_test = [y_test[i][1]*Tw_med for i in range(len(y_test))]
Tw_pred = [y_pred[i][1]*Tw_med for i in range(len(y_pred))]

Tw_data_norm = [y_train[i][1] for i in range(len(y_train))]
Tw_pred_norm = [y_pred[i][1] for i in range(len(y_pred))]
xe_data_norm = [y_train[i][0] for i in range(len(y_train))]
xe_pred_norm = [y_pred[i][0] for i in range(len(y_pred))]
#print(alpha_data)

#Plotting with log-log scale
plt.figure(figsize=(6,6))
plt.scatter(xe_pred, xe_data, c='r', label='$x_e$ output')
plt.plot(xe_data, xe_data, 'go-', alpha = 0.3, label='Unit slope')
plt.title('Comparison on training data for Exit quality $x_e$ predictions from NN vs. data points')
plt.xlabel(r"predicted $x_e$ (output NN)")
plt.ylabel(r"test data for $x_e$")
plt.legend()
plt.loglog()
plt.figure(figsize=(6,6))
plt.scatter(Tw_pred, Tw_train, c='b', label='$T_w$ output')
plt.plot(Tw_train, Tw_train, 'go-', alpha=0.4, label='Unit slope')
plt.legend()
plt.title('Same for second output, maximum temperature of wall')
plt.xlabel(r"predicted $T_w$ in °C (output NN)")
plt.ylabel(r"Test data for $T_w$")
plt.loglog()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.9999910593034">
# <img src="data:image/png;base64,..." width="599.9999910593034">

# %%
from sklearn.metrics import mean_absolute_error as mae
P_mae_e = mae(xe_data_norm, xe_pred_norm)
print('MAE with exit quality data points:', P_mae_e)

P_mae_f = mae(Tw_data_norm, Tw_pred_norm)
print('MAE with Tw data points:', P_mae_f)
# Out:
# MAE with exit quality data points: 0.029370124097188952
# MAE with Tw data points: 0.003519907555481383

# %% [markdown]
# ### Part f: predictions on test dataset

# %%
#Getting the predicted outputs by the model:
y_pred_test = []
for i in range(len(x_test)):
    xrow = [[x_test[i][0] , x_test[i][1] , x_test[i][2]]]
    out = model.predict(np.array(xrow))
    y_pred_test.append(out) 
y_pred_test = np.concatenate(y_pred_test, axis=0 )

# %%
import matplotlib.pyplot as plt
xe_data = [y_test[i][0] * xe_med for i in range(len(y_test))]
xe_pred = [y_pred_test[i][0] *xe_med for i in range(len(y_pred_test))]

Tw_train = [y_test[i][1]*Tw_med for i in range(len(y_test))]
Tw_pred = [y_pred_test[i][1]*Tw_med for i in range(len(y_pred_test))]

Tw_data_norm = [y_test[i][1] for i in range(len(y_test))]
Tw_pred_norm = [y_pred_test[i][1] for i in range(len(y_pred_test))]
xe_data_norm = [y_test[i][0] for i in range(len(y_test))]
xe_pred_norm = [y_pred_test[i][0] for i in range(len(y_pred_test))]
#print(alpha_data)

#Plotting with log-log scale
plt.figure(figsize=(6,6))
plt.scatter(xe_pred, xe_data, c='r', label='$x_e$ output')
plt.plot(xe_data, xe_data, 'go-', alpha = 0.3, label='Unit slope')
plt.title('Comparison on validation data for Exit quality $x_e$ predictions from NN vs. data points')
plt.xlabel(r"predicted $x_e$ (output NN)")
plt.ylabel(r"test data for $x_e$")
plt.legend()
plt.loglog()
plt.figure(figsize=(6,6))
plt.scatter(Tw_pred, Tw_train, c='b', label='$T_w$ output')
plt.plot(Tw_train, Tw_train, 'go-', alpha = 0.3, label='Unit slope')
plt.legend()
plt.title('Same for second output, maximum temperature of wall')
plt.xlabel(r"predicted $T_w$ in °C (output NN)")
plt.ylabel(r"Test data for $T_w$")
plt.loglog()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="599.9999910593034">
# <img src="data:image/png;base64,..." width="599.9999910593034">

# %%
from sklearn.metrics import mean_absolute_error as mae
P_mae_e = mae(xe_data_norm, xe_pred_norm)
print('MAE with exit quality validation data points:', P_mae_e)

P_mae_f = mae(Tw_data_norm, Tw_pred_norm)
print('MAE with Tw validation data points:', P_mae_f)
# Out:
# MAE with exit quality validation data points: 0.04593982277335698
# MAE with Tw validation data points: 0.0023938799144576596

# %% [markdown]
# ### Task g)

# %%
#xdata.append([ Di(m), qoflux (kW/m^2), mdot (kg/s)])
DI = np.linspace(7*10**(-3), 13*(10**-3), 1000)
q0 = np.array([750 for i in range(len(DI))])
mdot = np.linspace(0.05,0.15, 1000)


xdatag = np.vstack((DI, q0, mdot)).T
print(xdatag.shape)
#print(xdatag)
# Out:
# (1000, 3)

# %%
x_mediang = np.median(xdatag, 0)
DI_med = x_mediang[0] ###Median for the first input: tube diameter in m
q0_med = x_mediang[1]
mdot_med = x_mediang[2]
print('median of each input:', x_median)
x_normg = xdatah/x_median
print(len(x_normg))
# Out:
# median of each input: [1.100e-02 8.500e+02 9.265e-02]
# 1000

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker as mticker
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from matplotlib import rcParams
from matplotlib import cm
import sys
# %matplotlib notebook


#Getting the predicted power output by the model:
y_pred = []
for i in range(len(x_normg)):
    xrow = [[x_normg[i][0] , x_normg[i][1] , x_normg[i][2]]]
    out = model.predict(np.array(xrow))
    y_pred.append(out) 
y_pred = np.concatenate(y_pred, axis=0 )
xe_pred = [y_pred[i][0]*xe_med for i in range(len(y_pred))]
Tw_pred = [y_pred[i][1]*Tw_med for i in range(len(y_pred))]

X, Y = np.meshgrid(DI, mdot)
Z_xe = xe_pred + X - X
Z_Tw = Tw_pred + Y-Y

fig = plt.figure(figsize=(8,8))
ax = fig.gca(projection='3d')

surf = ax.plot_surface(X, Y, Z_xe, cmap = cm.coolwarm, linewidth=0, antialiased = False)

cax = fig.add_axes([0.25, .82, 0.5, 0.04])
fig.colorbar(surf, orientation='horizontal', cax=cax)

ax.set_xlabel(r"$DI$ ($m$)")
ax.set_ylabel(r"$\dot{m}$ ($kg/s$)")
ax.set_zlabel(r"$x_e$")
ax.set_title(r"Exit quality predictions in function of $DI$ and $\dot{m}$ with $q_0'' = 750 kW/m^2$")
rcParams['axes.labelpad'] = 20

ax.azim = -130
ax.dist=10
ax.elev=10

fig = plt.figure(figsize=(8,8))
ax = fig.gca(projection='3d')

surf = ax.plot_surface(X, Y, Z_Tw, cmap = cm.coolwarm, linewidth=0, antialiased = False)

cax = fig.add_axes([0.25, .82, 0.5, 0.04])
fig.colorbar(surf, orientation='horizontal', cax=cax)

ax.set_xlabel(r"$DI$ ($m$)")
ax.set_ylabel(r"$\dot{m}$ ($kg/s$)")
ax.set_zlabel(r"$T_w$ ($°C$)")
ax.set_title(r"Tw predictions in function of $DI$ and $\dot{m}$ with $q_0'' = 750 kW/m^2$")
rcParams['axes.labelpad'] = 20

ax.azim = -130
ax.dist=10
ax.elev=10


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="799.9999880790713">

# %% [markdown]
# ### Task 1.2)

# %%
from keras import backend as K
initializer = keras.initializers.RandomUniform(minval= -0.2, maxval=0.3)

model2 = keras.Sequential([
    keras.layers.Dense(6, activation=K.elu, input_shape=[3],  kernel_initializer=initializer),
    keras.layers.Dense(8, activation=K.elu,  kernel_initializer=initializer),
    keras.layers.Dropout(0.25),
    keras.layers.Dense(12, activation=K.elu,  kernel_initializer=initializer),
    keras.layers.Dropout(0.25),
    keras.layers.Dense(16, activation=K.elu,  kernel_initializer=initializer),
    keras.layers.Dropout(0.25),
    keras.layers.Dense(8, activation=K.elu, kernel_initializer=initializer),
    keras.layers.Dropout(0.25),
    keras.layers.Dense(2,  kernel_initializer=initializer)
  ])
model2.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_26 (Dense)             (None, 6)                 24
# _________________________________________________________________
# dense_27 (Dense)             (None, 8)                 56
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_28 (Dense)             (None, 12)                108
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 12)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 16)                208
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 16)                0
# ...

# %%
rms = keras.optimizers.RMSprop(0.0030)
model2.compile(loss='mean_absolute_error',optimizer=rms, metrics=['accuracy'])

# %%
# Add an early stopping callback
es = keras.callbacks.EarlyStopping(
    monitor='loss', 
    mode='min', 
    patience = 130, 
    restore_best_weights = True, 
    verbose=1)
# Add a checkpoint where loss is minimum, and save that model
mc = keras.callbacks.ModelCheckpoint('best_model.SB', monitor='loss', 
                     mode='min',  verbose=1, save_best_only=True)
import os
root_logdir = os.path.join(os.curdir, "my_logs")

def get_run_logdir():
    import time
    run_id = time.strftime("run_P1_2_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)
run_logdir = get_run_logdir()

tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

historyData = model2.fit(x_train, y_train,epochs=800,callbacks=[es, tensorboard_cb], validation_data = (x_test, y_test))
#historyData = model2.fit(x_train,y_train,epochs=800,callbacks=[es, tensorboard_cb])

loss_hist = historyData.history['loss']
#val_loss_hist = historyData.history['val_loss']

accuracy = historyData.history['accuracy']
#val_accuracy = historyData.history['val_accuracy']

#The above line will return a dictionary, access it's info like this:
best_epoch = np.argmin(historyData.history['loss']) + 1
print ('best epoch = ', best_epoch)
print('smallest loss =', np.min(loss_hist))

model2.save('./best_model_1_2')
# Out:
# Train on 39 samples, validate on 13 samples
# Epoch 1/800
# 39/39 [==============================] - 0s 980us/step - loss: 0.0647 - accuracy: 0.8718 - val_loss: 0.0477 - val_accuracy: 0.8462
# Epoch 2/800
# 39/39 [==============================] - 0s 271us/step - loss: 0.0643 - accuracy: 0.8462 - val_loss: 0.0479 - val_accuracy: 0.9231
# Epoch 3/800
# 39/39 [==============================] - 0s 361us/step - loss: 0.0614 - accuracy: 0.8718 - val_loss: 0.0464 - val_accuracy: 0.8462
# Epoch 4/800
# 39/39 [==============================] - 0s 315us/step - loss: 0.0559 - accuracy: 0.8462 - val_loss: 0.0459 - val_accuracy: 0.9231
# Epoch 5/800
# 39/39 [==============================] - 0s 296us/step - loss: 0.0563 - accuracy: 0.8462 - val_loss: 0.0826 - val_accuracy: 0.6923
# Epoch 6/800
# 39/39 [==============================] - 0s 283us/step - loss: 0.0726 - accuracy: 0.8718 - val_loss: 0.0447 - val_accuracy: 0.8462
# Epoch 7/800
# ...

# %%
recon_model = keras.models.load_model("best_model_1_2")

# %%
train_eval = model2.evaluate(x_train, y_train, verbose = 1)
print('Train loss:', train_eval[0])
print('Train accuracy:', train_eval[1])
#print(test_eval)
# Out:
# 39/39 [==============================] - 0s 121us/step
# Train loss: 0.04544343016086481
# Train accuracy: 0.7948718070983887

# %%
test_eval = model2.evaluate(x_test, y_test, verbose = 1)
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
print(test_eval)
# Out:
# 13/13 [==============================] - 0s 145us/step
# Test loss: 0.050914324820041656
# Test accuracy: 0.8461538553237915
# [0.050914324820041656, 0.8461538553237915]

# %%
epochs = range(len(accuracy))
plt.figure()
plt.plot(epochs, accuracy, 'b', label='train accuracy')
plt.plot(epochs, val_accuracy, 'r', label='val accuracy')
plt.legend()
plt.title('Training and validation accuracy')
plt.figure()
plt.plot(epochs, loss_hist, 'b', label='train loss')
plt.plot(epochs, val_loss_hist, 'r', label='val loss')
plt.title('Training and validation loss')

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-023a966c4027> in <module>
#       2 plt.figure()
#       3 plt.plot(epochs, accuracy, 'b', label='train accuracy')
# ----> 4 plt.plot(epochs, val_accuracy, 'r', label='val accuracy')
#       5 plt.legend()
#       6 plt.title('Training and validation accuracy')
#
# NameError: name 'val_accuracy' is not defined

# %%
#Getting the predicted outputs by the model:
#print(x_train)
y_pred_2 = []
for i in range(len(x_train)):
    xrow = [[x_train[i][0] , x_train[i][1] , x_train[i][2]]]
    #print(xrow)
    out = model2.predict(np.array(xrow))
    #print(out)
    y_pred_2.append(out) 
y_pred_2 = np.concatenate(y_pred_2, axis=0 )
print(y_pred_2.shape)
# Out:
# (39, 2)

# %%
import matplotlib.pyplot as plt
xe_data_2 = [y_train[i][0] * xe_med for i in range(len(y_train))]
xe_pred_2 = [y_pred_2[i][0] *xe_med for i in range(len(y_pred_2))]
print(len(xe_pred_2))
Tw_data_2 = [y_train[i][1]*Tw_med for i in range(len(y_train))]
Tw_pred_2 = [y_pred_2[i][1]*Tw_med for i in range(len(y_pred_2))]

Tw_data_norm_2 = [y_train[i][1] for i in range(len(y_train))]
Tw_pred_norm_2 = [y_pred_2[i][1] for i in range(len(y_pred_2))]
xe_data_norm_2 = [y_train[i][0] for i in range(len(y_train))]
xe_pred_norm_2 = [y_pred_2[i][0] for i in range(len(y_pred_2))]
#print(alpha_data)
print(len(xe_pred_norm_2))
#Plotting with log-log scale
plt.figure(figsize=(9,8))
plt.scatter(xe_pred_2, xe_data_2, c='r', label='$x_e$ output')
plt.plot(xe_data_2, xe_data_2, 'go-', alpha = 0.3, label='Unit slope')
plt.title('Comparison on training data for Exit quality $x_e$ predictions from NN vs. data points')
plt.xlabel(r"predicted $x_e$ (output NN)")
plt.ylabel(r"test data for $x_e$")
plt.legend()
plt.loglog()
plt.figure(figsize=(9,8))
plt.scatter(Tw_pred_norm, Tw_data_norm, c='b', label='$T_w$ output')
plt.plot(Tw_data_norm, Tw_data_norm, 'go-', alpha=0.4, label='Unit slope')
plt.legend()
plt.title('Same for second output, normalized maximum temperature of wall')
plt.xlabel(r"predicted $T_w$ in °C (output NN)")
plt.ylabel(r"Test data for $T_w$")
plt.loglog()
plt.show()
# Out:
# 39
# 39
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="899.9999865889552">

# %%
from sklearn.metrics import mean_absolute_error as mae
P_mae_e = mae(xe_data_norm, xe_pred_norm)
print('MAE with exit quality training data points:', P_mae_e)

P_mae_f = mae(Tw_data_norm, Tw_pred_norm)
print('MAE with Tw training data points:', P_mae_f)
# Out:
# MAE with exit quality training data points: 0.04593982277335698
# MAE with Tw training data points: 0.0023938799144576596

# %%
#Getting the predicted outputs by the model:
y_pred_test_2 = []
for i in range(len(x_test)):
    xrow = [[x_test[i][0] , x_test[i][1] , x_test[i][2]]]
    #print(xrow)
    out = model2.predict(np.array(xrow))
    #print(y_test[i][0], y_test[i][1])
    #print(out)
    y_pred_test_2.append(out) 
y_pred_test_2 = np.concatenate(y_pred_test_2, axis=0 )

# %%
import matplotlib.pyplot as plt
xe_pred_2 = []
xe_data_test = []
xe_data_test = [y_test[i][0] * xe_med for i in range(len(y_test))]
xe_pred_2 = [y_pred_test_2[i][0] *xe_med for i in range(len(y_pred_test_2))]
Tw_train_test = []
Tw_train_test = [y_test[i][1]*Tw_med for i in range(len(y_test))]
Tw_pred_test = [y_pred_test_2[i][1]*Tw_med for i in range(len(y_pred_test_2))]

Tw_data_norm_2 = [y_test[i][1] for i in range(len(y_test))]
Tw_pred_norm_2 = [y_pred_test_2[i][1] for i in range(len(y_pred_test_2))]
xe_data_norm_2 = [y_test[i][0] for i in range(len(y_test))]
xe_pred_norm_2 = [y_pred_test_2[i][0] for i in range(len(y_pred_test_2))]
#print(alpha_data)
print(Tw_pred_norm_2)
print(Tw_data_norm_2)
#Plotting with log-log scale
plt.figure(figsize=(9,8))
plt.scatter(xe_pred_norm_2, xe_data_norm_2, c='r', label='Normalized $x_e$ output')
plt.plot(xe_data_norm_2, xe_data_norm_2, 'go-', alpha = 0.3, label='Unit slope')
plt.title('Comparison on validation data for normalized Exit quality $x_e$ predictions from NN vs. data points')
plt.xlabel(r"predicted $x_e$ (output NN)")
plt.ylabel(r"test data for $x_e$")
plt.legend()
#plt.loglog()
plt.figure(figsize=(10,8))
plt.scatter(Tw_pred_norm_2, Tw_data_norm_2, c='b', label='Normalized $T_w$ output')
plt.plot(Tw_data_norm_2, Tw_data_norm_2, 'go-', alpha = 0.3, label='Unit slope')
plt.legend()
plt.title('Same for second output, normalized maximum temperature of wall')
plt.xlabel(r"predicted $T_w$ in °C (output NN)")
plt.ylabel(r"Test data for $T_w$")
#plt.loglog()
plt.show()
# Out:
# [0.98123515, 1.0213404, 1.0392284, 1.033659, 1.036082, 1.0220791, 1.0398561, 1.0372032, 1.0244741, 0.9897913, 1.0046637, 1.0222677, 0.98143536]
# [0.9635707253035773, 0.9826058418116179, 1.009845749917952, 0.9721037085658024, 0.9579914670167378, 1.0068920249425666, 0.9940925500492287, 1.0853298326222514, 0.9445356087955367, 0.9796521168362324, 0.9940925500492287, 0.9560223170331474, 1.017394158188382]
# <img src="data:image/png;base64,..." width="899.9999865889552">
# <img src="data:image/png;base64,..." width="999.999985098839">

# %%
from sklearn.metrics import mean_absolute_error as mae
P_mae_e = mae(xe_data_norm_2, xe_pred_norm_2)
print('MAE with exit quality validation data points:', P_mae_e)

P_mae_f = mae(Tw_data_norm_2, Tw_pred_norm_2)
print('MAE with Tw validation data points:', P_mae_f)
# Out:
# MAE with exit quality validation data points: 0.060493436476000285
# MAE with Tw validation data points: 0.04133521195828653

# %%
#xdata.append([ Di(m), qoflux (kW/m^2), mdot (kg/s)])
DI = np.linspace(7*10**(-3), 13*(10**-3), 1000)
q0 = 750
q0 = np.array([750 for i in range(len(DI))])
mdot = np.linspace(0.05,0.15, 1000)


xdatag = np.vstack((DI, q0, mdot)).T
print(xdatag.shape)
#print(xdatag)
# Out:
# (1000, 3)

# %%
x_mediang = np.median(xdatag, 0)
DI_med = x_mediang[0] ###Median for the first input: tube diameter in m
q0_med = x_mediang[1]
mdot_med = x_mediang[2]
print('median of each input:', x_mediang)
x_normg = xdatag/x_mediang
print(len(x_normg))
#print(x_normg)
# Out:
# median of each input: [1.0e-02 7.5e+02 1.0e-01]
# 1000

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker as mticker
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from matplotlib import rcParams
from matplotlib import cm
import sys
# %matplotlib notebook


#Getting the predicted power output by the model:
y_pred = []
for i in range(len(x_normg)):
    xrow = [[x_normg[i][0] , x_normg[i][1] , x_normg[i][2]]]
    out = model2.predict(np.array(xrow))
    y_pred.append(out) 
y_pred = np.concatenate(y_pred, axis=0 )
print(y_pred.shape)
xe_pred = [y_pred[i][0]*xe_med for i in range(len(y_pred))]
Tw_pred = [y_pred[i][1]*Tw_med for i in range(len(y_pred))]

X, Y = np.meshgrid(DI, mdot)
Z_xe = xe_pred + X - X
Z_Tw = Tw_pred + Y-Y

fig = plt.figure(figsize=(8,8))
ax = fig.gca(projection='3d')

surf = ax.plot_surface(X, Y, Z_xe, cmap = cm.coolwarm, linewidth=0, antialiased = False)

cax = fig.add_axes([0.25, .82, 0.5, 0.04])
fig.colorbar(surf, orientation='horizontal', cax=cax)

ax.set_xlabel(r"$DI$ ($m$)")
ax.set_ylabel(r"$\dot{m}$ ($kg/s$)")
ax.set_zlabel(r"$x_e$")
ax.set_title(r"Exit quality predictions in function of $DI$ and $\dot{m}$ with $q_0'' = 750 kW/m^2$")
rcParams['axes.labelpad'] = 20

ax.azim = -130
ax.dist=10
ax.elev=10

fig = plt.figure(figsize=(8,8))
ax = fig.gca(projection='3d')

surf = ax.plot_surface(X, Y, Z_Tw, cmap = cm.coolwarm, linewidth=0, antialiased = False)

cax = fig.add_axes([0.25, .82, 0.5, 0.04])
fig.colorbar(surf, orientation='horizontal', cax=cax)

ax.set_xlabel(r"$DI$ ($m$)")
ax.set_ylabel(r"$\dot{m}$ ($kg/s$)")
ax.set_zlabel(r"$T_w$ ($°C$)")
ax.set_title(r"Tw predictions in function of $DI$ and $\dot{m}$ with $q_0'' = 750 kW/m^2$")
rcParams['axes.labelpad'] = 20

ax.azim = -130
ax.dist=10
ax.elev=10


plt.show()
# Out:
# (1000, 2)
# <img src="data:image/png;base64,..." width="799.9999880790713">
# <img src="data:image/png;base64,..." width="799.9999880790713">

# %% [markdown]
# # Task 1.3

# %%
import numpy

xdata = []
ydata = []
#xdata.append([ Di(m), qoflux (kW/m^2), exit quality, max wall temperature (deg C)])

xdata.append([0.008, 550, 0.525, 306.7])
xdata.append([0.008, 650, 0.525, 298.5])
xdata.append([0.008, 750, 0.525, 294.5])
xdata.append([0.008, 850, 0.525, 290.2])
xdata.append([0.008, 950, 0.524, 286.9])
xdata.append([0.008, 1050, 0.524, 284.1])
xdata.append([0.008, 1150, 0.525, 281.7])
xdata.append([0.008, 850, 0.524, 290.31])
xdata.append([0.008, 550, 0.734, 307.9])
xdata.append([0.008, 750, 0.735, 295.5])
xdata.append([0.008, 950, 0.735, 287.8])
xdata.append([0.008, 1050, 0.735, 285.0])
xdata.append([0.008, 1150, 0.735, 282.5])
xdata.append([0.008, 850, 0.734, 291.3])
xdata.append([0.008, 550,  0.945, 308.6])
xdata.append([0.008, 750, 0.945, 296.2])
xdata.append([0.008, 950, 0.945, 288.5])
xdata.append([0.008, 1150, 0.945, 283.1])
xdata.append([0.008, 850, 0.945, 291.9])
xdata.append([0.011, 550,  0.525, 328.0])
xdata.append([0.011, 750, 0.525, 311.2])
xdata.append([0.011, 950, 0.525, 300.8])
xdata.append([0.011, 1150, 0.525, 293.6])
xdata.append([0.011, 850, 0.525, 305.5])
xdata.append([0.011, 550, 0.735, 329.6])
xdata.append([0.011, 750, 0.735, 312.6])
xdata.append([0.011, 950, 0.735, 302.0])
xdata.append([0.011, 1050, 0.735, 299.4])
xdata.append([0.011, 1150, 0.735, 294.8])
xdata.append([0.011, 850, 0.735, 306.8])
xdata.append([0.011, 550,  0.945, 330.7])
xdata.append([0.011, 750, 0.945, 313.6])
xdata.append([0.011, 950, 0.944, 302.9])
xdata.append([0.011, 1150, 0.945, 295.6])
xdata.append([0.011, 850, 0.944, 307.7])
xdata.append([0.011, 700, 0.734, 324.7])
xdata.append([0.013, 550, 0.525, 342.2])
xdata.append([0.013, 750, 0.524,  322.3])
xdata.append([0.013, 950, 0.524, 310.0])
xdata.append([0.013, 1150, 0.525, 301.6])
xdata.append([0.013, 850, 0.524, 315.5])
xdata.append([0.013, 550, 0.734, 344.1])
xdata.append([0.013, 750, 0.735, 324.0])
xdata.append([0.013, 950, 0.735, 311.5])
xdata.append([0.013, 1050, 0.735, 306.3])
xdata.append([0.013, 1150, 0.735, 302.9])
xdata.append([0.013, 850, 0.734, 317.1])
xdata.append([0.013, 550, 0.945, 345.3])
xdata.append([0.013, 750, 0.944, 325.1])
xdata.append([0.013, 950, 0.944, 312.5])
xdata.append([0.013, 1150, 0.945, 303.9])
xdata.append([0.013, 850, 0.945, 318.2])


#data.append([mdot (kg/s)])

ydata.append([0.06157])
ydata.append([0.07269])
ydata.append([0.08396])
ydata.append([0.09347])
ydata.append([0.10635])
ydata.append([0.11521])
ydata.append([0.1287])
ydata.append([0.09516])
ydata.append([0.04398])
ydata.append([0.05997])
ydata.append([0.07596])
ydata.append([0.08343])
ydata.append([0.0919])
ydata.append([0.06797])
ydata.append([0.0342])
ydata.append([0.04664])
ydata.append([0.05908])
ydata.append([0.0715])
ydata.append([0.05286])
ydata.append([0.0846])
ydata.append([0.1154])
ydata.append([0.1462])
ydata.append([0.177])
ydata.append([0.1308])
ydata.append([0.06047])
ydata.append([0.08246])
ydata.append([0.1044])
ydata.append([0.1134])
ydata.append([0.1264])
ydata.append([0.0934])
ydata.append([0.047])
ydata.append([0.06413])
ydata.append([0.08124])
ydata.append([0.09834])
ydata.append([0.072691])
ydata.append([0.087196])
ydata.append([0.10005])
ydata.append([0.13644])
ydata.append([0.17282])
ydata.append([0.2092])
ydata.append([0.15463])
ydata.append([0.07147])
ydata.append([0.09745])
ydata.append([0.12344])
ydata.append([0.13302])
ydata.append([0.1494])
ydata.append([0.11045])
ydata.append([0.05558])
ydata.append([0.0758])
ydata.append([0.09601])
ydata.append([0.1162])
ydata.append([0.0859])

xarray= numpy.array(xdata)
yarray= numpy.array(ydata)

# %%
x_median = np.median(xarray, 0)
DI_med = x_median[0] ###Median for the first input:Tube inside diameter Di (m)
qoflux_med = x_median[1]
xe_med = x_median[2]
Tw_med = x_median[3]
print('Median of each input:', x_median)
print('output median :', mdot_med)

x_norm = xarray/x_median
#print('Normalized input array: ', x_norm)

y_median = np.median(yarray, 0)
mdot_med = y_median[0] ###Median for the first output: mdot

y_norm = yarray/y_median
#print('Normalized output array:', y_norm)
# Out:
# Median of each input: [1.100e-02 8.500e+02 7.350e-01 3.047e+02]
# output median : 0.1

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_norm, y_norm, test_size=0.25, random_state = 7)

# %%
print('Length of training set:', len(x_train),'; Length of testing set:', len(x_test))
#print(len(y_train))
print('Length of the entire set:', len(x_norm))
# Out:
# Length of training set: 39 ; Length of testing set: 13
# Length of the entire set: 52

# %%
from keras import backend as K
initializer = keras.initializers.RandomUniform(minval= -0.2, maxval=0.5)

model3 = keras.Sequential([
    keras.layers.Dense(6, activation=K.elu, input_shape=[4],  kernel_initializer=initializer),
    keras.layers.Dense(8, activation=K.elu,  kernel_initializer=initializer),
    keras.layers.Dense(16, activation=K.elu,  kernel_initializer=initializer),
    keras.layers.Dense(8, activation=K.elu, kernel_initializer=initializer),
    keras.layers.Dense(1,  kernel_initializer=initializer)
  ])
model3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 6)                 30
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 56
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                144
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 9
# ...
# Total params: 375
# Trainable params: 375
# Non-trainable params: 0
# _________________________________________________________________

# %%
rms = keras.optimizers.RMSprop(0.0030)
model3.compile(loss='mean_absolute_error',optimizer = rms, metrics = ['accuracy'])

# %%
# Add an early stopping callback
es = keras.callbacks.EarlyStopping(
    monitor='loss', 
    mode='min', 
    patience = 130, 
    restore_best_weights = True, 
    verbose=1)
# Add a checkpoint where loss is minimum, and save that model
mc = keras.callbacks.ModelCheckpoint('best_model.SB', monitor='loss', 
                     mode='min',  verbose=1, save_best_only=True)
import os
root_logdir = os.path.join(os.curdir, "my_logs")

def get_run_logdir():
    import time
    run_id = time.strftime("run_P1_3_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)
run_logdir = get_run_logdir()

tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

historyData = model3.fit(x_train, y_train,epochs=800,callbacks=[es, tensorboard_cb], validation_data = (x_test, y_test))
#historyData = model3.fit(x_train,y_train,epochs=800,callbacks=[es, tensorboard_cb])

loss_hist = historyData.history['loss']
#The above line will return a dictionary, access it's info like this:
best_epoch = np.argmin(historyData.history['loss']) + 1
print ('best epoch = ', best_epoch)
print('smallest loss =', np.min(loss_hist))

model.save('./best_model_3')
# Out:
# Train on 39 samples, validate on 13 samples
# Epoch 1/800
# 39/39 [==============================] - 1s 34ms/step - loss: 0.1163 - accuracy: 0.0000e+00 - val_loss: 0.0503 - val_accuracy: 0.0000e+00
# Epoch 2/800
# 39/39 [==============================] - 0s 209us/step - loss: 0.0454 - accuracy: 0.0000e+00 - val_loss: 0.0296 - val_accuracy: 0.0000e+00
# Epoch 3/800
# 39/39 [==============================] - 0s 222us/step - loss: 0.0399 - accuracy: 0.0000e+00 - val_loss: 0.0388 - val_accuracy: 0.0000e+00
# Epoch 4/800
# 39/39 [==============================] - 0s 206us/step - loss: 0.0390 - accuracy: 0.0000e+00 - val_loss: 0.0362 - val_accuracy: 0.0000e+00
# Epoch 5/800
# 39/39 [==============================] - 0s 188us/step - loss: 0.0547 - accuracy: 0.0000e+00 - val_loss: 0.0329 - val_accuracy: 0.0000e+00
# Epoch 6/800
# 39/39 [==============================] - 0s 187us/step - loss: 0.0495 - accuracy: 0.0000e+00 - val_loss: 0.0287 - val_accuracy: 0.0000e+00
# Epoch 7/800
# ...

# %% [markdown]
# ### Predictions of the model 3 on the training data set

# %%
#Getting the predicted outputs by the model:
y_pred = []
for i in range(len(x_train)):
    xrow = [[x_train[i][0] , x_train[i][1] , x_train[i][2], x_train[i][3]]]
    out = model3.predict(np.array(xrow))
    y_pred.append(out) 
y_pred = np.concatenate(y_pred, axis=0 )

# %%
import matplotlib.pyplot as plt
mdot_data = [y_train[i][0] * mdot_med for i in range(len(y_train))]
mdot_pred = [y_pred[i][0] *mdot_med for i in range(len(y_pred))]

mdot_data_norm = [y_train[i][0] for i in range(len(y_train))]
mdot_pred_norm = [y_pred[i][0] for i in range(len(y_pred))]
#print(alpha_data)

#Plotting with log-log scale
plt.figure(figsize=(9,8))
plt.scatter(mdot_pred, mdot_data, c='r', label='$\dot{m}$ output')
plt.plot(mdot_data, mdot_data, 'go-', alpha = 0.3, label='Unit slope')
plt.title('Comparison on validation data for flow mass rate $\dot{m}$ predictions from NN vs. data points')
plt.xlabel(r"Predicted $\dot{m}$ (output NN)")
plt.ylabel(r"Test data for $\dot{m}$")
plt.legend()
plt.loglog()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="899.9999865889552">

# %%
from sklearn.metrics import mean_absolute_error as mae
P_mae_e = mae(mdot_data_norm, mdot_pred_norm)
print('MAE with flow mass data points:', P_mae_e)
# Out:
# MAE with flow mass data points: 0.0333092517165046

# %% [markdown]
# ### Predictions on the validation data set

# %%
#Getting the predicted outputs by the model:
y_pred_test = []
for i in range(len(x_test)):
    xrow = [[x_test[i][0] , x_test[i][1] , x_test[i][2], x_test[i][3]]]
    out = model3.predict(np.array(xrow))
    y_pred_test.append(out) 
y_pred_test = np.concatenate(y_pred_test, axis=0 )

# %%
import matplotlib.pyplot as plt
mdot_data = [y_test[i][0] * mdot_med for i in range(len(y_test))]
mdot_pred = [y_pred_test[i][0] *mdot_med for i in range(len(y_pred_test))]

mdot_data_norm = [y_test[i][0] for i in range(len(y_test))]
mdot_pred_norm = [y_pred_test[i][0] for i in range(len(y_pred_test))]
#print(alpha_data)

#Plotting with log-log scale
plt.figure(figsize=(9,8))
plt.scatter(mdot_pred, mdot_data, c='r', label='$\dot{m}$ output')
plt.plot(mdot_data, mdot_data, 'go-', alpha = 0.3, label='Unit slope')
plt.title('Comparison on validation data for flow mass rate $\dot{m}$ predictions from NN vs. data points')
plt.xlabel(r"Predicted $\dot{m}$ (output NN)")
plt.ylabel(r"Test data for $\dot{m}$")
plt.legend()
plt.loglog()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="899.9999865889552">

# %%
from sklearn.metrics import mean_absolute_error as mae
P_mae_e = mae(mdot_data_norm, mdot_pred_norm)
print('MAE with exit flow mass rate validation data points:', P_mae_e)
# Out:
# MAE with exit flow mass rate validation data points: 0.01873649963510506

# %% [markdown]
# ### Model-based control scheme

# %%
#xdata.append([ Di(m), qoflux (kW/m^2), xe, Tw])
q0 = np.linspace(500, 800, 1000)
DI = np.array([0.010 for i in range(len(q0))])
xe = np.array([0.70 for i in range(len(q0))])
Tw = np.array([300 for i in range(len(q0))])


xdatag = np.vstack((DI, q0, xe, Tw)).T
print(xdatag.shape)
#print(xdatag)
# Out:
# (1000, 4)

# %%
x_mediang = np.median(xdatag, 0)
DI_med = x_mediang[0] ###Median for the first input: tube diameter in m
q0_med = x_mediang[1]
xe_med = x_mediang[2]
Tw_med = x_mediang[3]
print('median of each input:', x_mediang)
x_normg = xdatag/x_mediang
print(len(x_normg))
#print(x_normg)
# Out:
# median of each input: [1.0e-02 6.5e+02 7.0e-01 3.0e+02]
# 1000

# %%
#Getting the predicted power output by the model:
y_pred = []
for i in range(len(x_normg)):
    xrow = [[x_normg[i][0] , x_normg[i][1] , x_normg[i][2], x_normg[i][3]]]
    out = model3.predict(np.array(xrow))
    y_pred.append(out) 
y_pred = np.concatenate(y_pred, axis=0 )
print(y_pred.shape)
mdot_pred = [y_pred[i][0]*mdot_med for i in range(len(y_pred))]
plt.figure(figsize=(9,8))
plt.plot(q0, mdot_pred, c='r', label='$\dot{m}$ output')
#plt.plot(mdot_pred, q0, c='b', label='$\dot{m}$ output')

plt.title('Variation of $\dot{m}$ in function of $q_0$')
plt.ylabel(r"Predictions $\dot{m}$")
plt.xlabel(r"Incident solar flux $q_0$ ($kW/m^2$)")
plt.legend()
#plt.loglog()
plt.show()
# Out:
# (1000, 1)
# <img src="data:image/png;base64,..." width="899.9999865889552">

# %% [markdown]
# # Part 2

# %% [markdown]
# ### a)

# %%
#import useful packages
import keras
import pandas as pd
from keras.models import Sequential
import numpy as np
import keras.backend as kb
import tensorflow as tf
#the follwoing 2 lines are only needed for Mac OS machines
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import numpy as np
 
xdata = []
ydata = []

#xdata.append([qflux1 (W/m^2), qflux2 (W/m^2), separation distance (m)])
xdata.append([200.0,  100.0, 0.000])
xdata.append([200.0,  400.0, 0.000])
xdata.append([200.0,  200.0, 0.000])
xdata.append([500.0,  400.0, 0.000])
xdata.append([100.0,  300.0, 0.000])
xdata.append([600.0,  300.0, 0.002])
xdata.append([500.0,  400.0, 0.002])
xdata.append([200.,  400.0, 0.002])
xdata.append([100.0,  300.0, 0.002])
xdata.append([200.0,  200.0, 0.002])
xdata.append([200.0,  100.0, 0.002])
xdata.append([100.0,  200.0, 0.002])
xdata.append([500.0,  400.0, 0.004])
xdata.append([300.0,  400.0, 0.004])
xdata.append([200.0,  400.0, 0.004])
xdata.append([100.0,  400.0, 0.004])
xdata.append([100.0,  300.0, 0.004])
xdata.append([200.0,  300.0, 0.004])
xdata.append([500.0,  300.0, 0.004])
xdata.append([200.0,  100.0, 0.004])
xdata.append([100.0,  200.0, 0.004])
xdata.append([200.0,  200.0, 0.004])
xdata.append([300.0,  200.0, 0.004])
xdata.append([100.0,  300.0, 0.006])
xdata.append([200.0,  400.0, 0.006])
xdata.append([400.0,  200.0, 0.006])
xdata.append([600.0,  300.0, 0.006])
xdata.append([300.0,  600.0, 0.006])
xdata.append([200.0,  100.0, 0.006])
xdata.append([100.0,  200.0, 0.006])
xdata.append([50.0,  200.0, 0.006])
xdata.append([350.0,  150.0, 0.004])
xdata.append([350.0,  150.0, 0.008])
xdata.append([300.0,  200.0, 0.008])
xdata.append([200.0,  100.0, 0.008])
xdata.append([250.0,  50.0, 0.008])
xdata.append([50.0,  250.0, 0.008])
xdata.append([400.0,  300.0, 0.008])
xdata.append([500.0,  400.0, 0.008])
xdata.append([50.0,  200.0, 0.010])
xdata.append([100.0,  200.0, 0.010])
xdata.append([200.0,  200.0, 0.010])
xdata.append([300.0,  200.0, 0.010])
xdata.append([500.0,  400.0, 0.010])
xdata.append([400.0,  300.0, 0.010])
xdata.append([100.0,  100.0, 0.010])
xdata.append([200.0,  100.0, 0.010])

#xdata.append([maximum surface temperature (deg C)])
ydata.append([52.7])
ydata.append([72.2])
ydata.append([56.0])
ydata.append([77.2])
ydata.append([62.8])
ydata.append([84.6])
ydata.append([77.2])
ydata.append([71.6])
ydata.append([62.4])
ydata.append([55.3])
ydata.append([52.7])
ydata.append([53.9])
ydata.append([77.2])
ydata.append([72.2])
ydata.append([71.1])
ydata.append([70.2])
ydata.append([62.2])
ydata.append([63.2])
ydata.append([77.2])
ydata.append([52.7])
ydata.append([53.6])
ydata.append([54.8])
ydata.append([61.4])
ydata.append([62.0])
ydata.append([70.8])
ydata.append([69.5])
ydata.append([84.6])
ydata.append([86.4])
ydata.append([52.7])
ydata.append([53.4])
ydata.append([53.0])
ydata.append([65.5])
ydata.append([65.5])
ydata.append([61.4])
ydata.append([52.7])
ydata.append([57.1])
ydata.append([57.4])
ydata.append([69.5])
ydata.append([77.2])
ydata.append([52.9])
ydata.append([53.2])
ydata.append([53.9])
ydata.append([61.4])
ydata.append([77.2])
ydata.append([69.5])
ydata.append([43.6])
ydata.append([52.7])


xarray= np.array(xdata)
yarray= np.array(ydata)
#print (xdata)
#print (xarray)
#print (ydata)
#print (yarray)

# %%
x_median = np.median(xarray, 0)
q1_med = x_median[0] ###Median for the first input:Tube inside diameter Di (m)
q2_med = x_median[1]
xs_med = x_median[2]
print('Median of each input:', x_median)
print('output median :', Ts_med)

x_norm = xarray/x_median
#print('Normalized input array: ', x_norm)

y_median = np.median(yarray, 0)
Ts_med = y_median[0] ###Median for the first output: Ts,max

y_norm = yarray/y_median
#print('Normalized output array:', y_norm)
# Out:
# Median of each input: [2.e+02 2.e+02 4.e-03]
# output median : 62.2

# %% [markdown]
# ### b)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_norm, y_norm, test_size=0.25, random_state = 7)

# %%
print('Length of training set:', len(x_train),'; Length of testing set:', len(x_test))
#print(len(y_train))
print('Length of the entire set:', len(x_norm))
# Out:
# Length of training set: 35 ; Length of testing set: 12
# Length of the entire set: 47

# %%
from keras import backend as K
#initialize weights with values between -0.2 and 1.2
initializer = keras.initializers.RandomUniform(minval= -0.2, maxval=0.5)

model4 = keras.Sequential([
    keras.layers.Dense(6, activation=K.elu, input_shape=[3],  kernel_initializer=initializer),
    keras.layers.Dense(8, activation=K.elu,  kernel_initializer=initializer),
    keras.layers.Dense(16, activation=K.elu,  kernel_initializer=initializer),
    keras.layers.Dense(8, activation=K.elu, kernel_initializer=initializer),
    keras.layers.Dense(1,  kernel_initializer=initializer)
  ])
model4.summary()

"""
    keras.layers.Dense(16, activation=K.elu, input_shape=[3],  kernel_initializer=initializer),
    keras.layers.Dense(32, activation=K.elu,  kernel_initializer=initializer),
    keras.layers.Dense(16, activation=K.elu, kernel_initializer=initializer),
    keras.layers.Dense(2,  kernel_initializer=initializer)

"""
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_15 (Dense)             (None, 6)                 24
# _________________________________________________________________
# dense_16 (Dense)             (None, 8)                 56
# _________________________________________________________________
# dense_17 (Dense)             (None, 16)                144
# _________________________________________________________________
# dense_18 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 9
# ...
# Total params: 369
# Trainable params: 369
# Non-trainable params: 0
# _________________________________________________________________
# ...

# %%
rms = keras.optimizers.RMSprop(0.0020)
model4.compile(loss='mean_absolute_error',optimizer=rms)

# %%
es = keras.callbacks.EarlyStopping(
    monitor='loss', 
    mode='min', 
    patience = 150, 
    restore_best_weights = True, 
    verbose=1)
# Add a checkpoint where loss is minimum, and save that model
mc = keras.callbacks.ModelCheckpoint('best_model.SB', monitor='loss', 
                     mode='min',  verbose=1, save_best_only=True)
import os
root_logdir = os.path.join(os.curdir, "my_logs")

def get_run_logdir():
    import time
    run_id = time.strftime("run_P1_3_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)
run_logdir = get_run_logdir()

tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

historyData = model4.fit(x_train,y_train,epochs=800,callbacks=[es, tensorboard_cb], validation_data = (x_test, y_test))

loss_hist = historyData.history['loss']
#The above line will return a dictionary, access it's info like this:
best_epoch = np.argmin(historyData.history['loss']) + 1
print ('best epoch = ', best_epoch)
print('smallest loss =', np.min(loss_hist))

model4.save('./best_model')
# Out:
# Train on 35 samples, validate on 12 samples
# Epoch 1/800
# 35/35 [==============================] - 1s 24ms/step - loss: 0.0667 - val_loss: 0.0259
# Epoch 2/800
# 35/35 [==============================] - 0s 226us/step - loss: 0.0459 - val_loss: 0.0158
# Epoch 3/800
# 35/35 [==============================] - 0s 246us/step - loss: 0.0317 - val_loss: 0.0110
# Epoch 4/800
# 35/35 [==============================] - 0s 313us/step - loss: 0.0293 - val_loss: 0.0128
# Epoch 5/800
# 35/35 [==============================] - 0s 292us/step - loss: 0.0211 - val_loss: 0.0099
# Epoch 6/800
# 35/35 [==============================] - 0s 281us/step - loss: 0.0193 - val_loss: 0.0138
# Epoch 7/800
# 35/35 [==============================] - 0s 274us/step - loss: 0.0190 - val_loss: 0.0161
# Epoch 8/800
# 35/35 [==============================] - 0s 333us/step - loss: 0.0213 - val_loss: 0.0119
# Epoch 9/800
# 35/35 [==============================] - 0s 317us/step - loss: 0.0177 - val_loss: 0.0079
# ...

# %%
recon_model = keras.models.load_model("best_model")

# %% [markdown]
# ### c) Comparison with the training data points

# %%
#Getting the predicted outputs by the model:
y_pred = []
for i in range(len(x_train)):
    xrow = [[x_train[i][0] , x_train[i][1] , x_train[i][2]]]
    out = model4.predict(np.array(xrow))
    y_pred.append(out) 
y_pred = np.concatenate(y_pred, axis=0 )

# %%
import matplotlib.pyplot as plt
Ts_data = [y_train[i][0] * Ts_med for i in range(len(y_train))]
Ts_pred = [y_pred[i][0] * Ts_med for i in range(len(y_pred))]

Ts_data_norm = [y_train[i][0] for i in range(len(y_train))]
Ts_pred_norm = [y_pred[i][0] for i in range(len(y_pred))]
#print(alpha_data)

#Plotting with log-log scale
plt.figure(figsize=(9,8))
plt.scatter(Ts_pred, Ts_data, c='r', label='$T_{S,max}$ output')
plt.plot(Ts_data, Ts_data, 'go-', alpha = 0.3, label='Unit slope')
plt.title('Comparison on training data for $T_{S,max}$ predictions from NN vs. data points')
plt.xlabel(r"Predicted $T_{S,max}$ (output NN)")
plt.ylabel(r"Training data for $T_{S,max}$")
plt.legend()
plt.loglog()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error as mae
P_mae_d = mae(Ts_data_norm, Ts_pred_norm)
print('MAE with Ts,max points:', P_mae_d)
# Out:
# MAE with Ts,max points: 0.012193715134289037

# %% [markdown]
# ### e) Same but with the validation points

# %%
#Getting the predicted outputs by the model:
y_pred = []
for i in range(len(x_test)):
    xrow = [[x_test[i][0] , x_test[i][1] , x_test[i][2]]]
    out = model4.predict(np.array(xrow))
    y_pred.append(out) 
y_pred = np.concatenate(y_pred, axis=0 )

# %%
import matplotlib.pyplot as plt
Ts_data = [y_test[i][0] * Ts_med for i in range(len(y_test))]
Ts_pred = [y_pred[i][0] * Ts_med for i in range(len(y_pred))]

Ts_data_norm = [y_test[i][0] for i in range(len(y_test))]
Ts_pred_norm = [y_pred[i][0] for i in range(len(y_pred))]
#print(alpha_data)

#Plotting with log-log scale
plt.figure(figsize=(9,8))
plt.scatter(Ts_pred, Ts_data, c='r', label='$T_{S,max}$ output')
plt.plot(Ts_data, Ts_data, 'go-', alpha = 0.3, label='Unit slope')
plt.title('Comparison of validation data for $T_{S,max}$ predictions from NN vs. data points')
plt.xlabel(r"Predicted $T_{S,max}$ (output NN)")
plt.ylabel(r"Test data for $T_{S,max}$")
plt.legend()
plt.loglog()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error as mae
P_mae_d = mae(Ts_data_norm, Ts_pred_norm)
print('MAE with Ts,max points:', P_mae_d)
# Out:
# MAE with Ts,max points: 0.012313193159471353

# %% [markdown]
# ### h) Surface plot

# %%
#xdata.append([qflux1 (W/m^2), qflux2 (W/m^2), separation distance (m)])
q1_2 = np.linspace(100, 500, 1000)
xs = np.linspace(0.00,0.015, 1000)


xdatag = np.vstack((q1_2, q1_2, xs)).T
print(xdatag.shape)
#print(xdatag)
# Out:
# (1000, 3)

# %%
x_mediang = np.median(xdatag, 0)
q1_2_med = x_mediang[0] ###Median for the first & second input: heat flux 1
xs_med = x_mediang[2]
print('median of each input:', x_mediang)
x_normg = xdatag/x_mediang
print(len(x_normg))
#print(x_normg)
# Out:
# median of each input: [3.0e+02 3.0e+02 7.5e-03]
# 1000

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.ticker as mticker
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from matplotlib import rcParams
from matplotlib import cm
import sys
# %matplotlib notebook


#Getting the predicted power output by the model:
y_pred = []
for i in range(len(x_normg)):
    xrow = [[x_normg[i][0] , x_normg[i][1] , x_normg[i][2]]]
    out = model4.predict(np.array(xrow))
    y_pred.append(out) 
y_pred = np.concatenate(y_pred, axis=0 )
print(y_pred.shape)
Ts_pred = [y_pred[i][0]*Ts_med for i in range(len(y_pred))]

X, Y = np.meshgrid(q1_2, xs)
Z = Ts_pred + X - X

fig = plt.figure(figsize=(8,8))
ax = fig.gca(projection='3d')

surf = ax.plot_surface(X, Y, Z, cmap = cm.coolwarm, linewidth=0, antialiased = False)

cax = fig.add_axes([0.25, .82, 0.5, 0.04])
fig.colorbar(surf, orientation='horizontal', cax=cax)

ax.set_xlabel(r" $q_{1&2}$($W/m^2$)")
ax.set_ylabel(r"$\Delta{x_s}$ ($m$)")
ax.set_zlabel(r"$T_{S,max}$")
ax.set_title(r"$T_{S,max}$ predictions in function of $q_1 = q_2$($W/m^2$) & $\Delta{x_s}$ (m)")
rcParams['axes.labelpad'] = 20

ax.azim = -130
ax.dist=10
ax.elev=10


plt.show()
# Out:
# (1000, 1)
# <img src="data:image/png;base64,..." width="799.9999880790713">
